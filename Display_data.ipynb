# %%
import pandas as pd

# %%
STO_3G=pd.read_csv('./data/STO_3G.csv')
STO_6G=pd.read_csv('./data/STO_6G.csv')
_321G=pd.read_csv('./data/_321G.csv')
_631G=pd.read_csv('./data/_631G.csv')
cc_pVTZ=pd.read_csv('./data/cc_pVTZ.csv')
aug_cc_pVQZ=pd.read_csv('./data/aug_cc_pVQZ.csv')
def2_TZVP=pd.read_csv('./data/def2_TZVP.csv')
def2_QZVPP=pd.read_csv('./data/def2_QZVPP.csv')

# %%
display(STO_3G)
display(STO_6G)
display(_321G)
display(_631G)
display(cc_pVTZ)
display(aug_cc_pVQZ)
display(def2_TZVP)
display(def2_QZVPP)
# Out:
#      Basis set Reference Target  APDFT$n$  Bond length  $|\Delta \rho|$  \
# 0        sto3G       HAl   HeMg         1          1.3         3.368281
# 1        sto3G       HAl   HeMg         2          1.3         3.368281
# 2        sto3G       HAl   HeMg         3          1.3         3.368281
# 3        sto3G       HAl   HeMg         4          1.3         3.368281
# 4        sto3G       HAl   HeMg         5          1.3         3.368281
# ...        ...       ...    ...       ...          ...              ...
# 4195     sto3G        NN     CO         1          3.2         3.281384
# 4196     sto3G        NN     CO         2          3.2         3.281384
# 4197     sto3G        NN     CO         3          3.2         3.281384
# 4198     sto3G        NN     CO         4          3.2         3.281384
# 4199     sto3G        NN     CO         5          3.2         3.281384
#
#       $E^{\text{APDFT}}$  $ E^{\text{T[R]}}$  $E^{\text{CCSD}}$  \
# ...
