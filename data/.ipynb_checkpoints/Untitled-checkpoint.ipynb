# %%
import pandas as pd

# %%
_321G=pd.read_pickle('./321G')
_631G=pd.read_pickle('./631G')

# %%
_631G
# Out:
#       alchemy  distance basis_set      e_alch      e_ccsd  ref target  \
# 0           0       1.3     631G* -198.156598 -200.788585  HAl   HeMg
# 1           1       1.3     631G* -198.904953 -200.788585  HAl   HeMg
# 2           2       1.3     631G* -199.062927 -200.788585  HAl   HeMg
# 3           3       1.3     631G* -199.065089 -200.788585  HAl   HeMg
# 4           4       1.3     631G* -199.061148 -200.788585  HAl   HeMg
# ...       ...       ...       ...         ...         ...  ...    ...
# 4195        0       3.2     631G* -109.291005 -112.788871   NN     CO
# 4196        1       3.2     631G* -110.774843 -112.788871   NN     CO
# 4197        2       3.2     631G* -110.774843 -112.788871   NN     CO
# 4198        3       3.2     631G* -110.988831 -112.788871   NN     CO
# 4199        4       3.2     631G* -110.988831 -112.788871   NN     CO
#
#        abs_err  delta_rho  e_at_ref_bs  err_alch
# 0     2.631987   3.755760  -199.055762  0.899164
# ...
